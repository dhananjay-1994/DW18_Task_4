# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
a = pd.read_csv('college_1.csv')
b = pd.read_csv('college_2.csv')

df = pd.merge(a,b, how='outer')
print(df)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
a = df.groupby(['python','Department'])
print(a.first(10))
# Out:
#                                                   mysql  Previous Geekions  \
# python Department
# -1.0   Computer Science and Engineering            24.0               8790
#        Electronics and Communication Engineering   35.0              10040
#        Electronics and Electrical Engineering      24.0               9150
#  0.0   Computer Science and Engineering             0.0              14150
#        Electronics and Communication Engineering  100.0               1020
#        Electronics and Electrical Engineering       0.0                  0
#  3.0   Electronics and Communication Engineering   39.0                770
#  11.0  Electronics and Communication Engineering   20.0                580
#  16.0  Computer Science and Engineering            24.0               6060
#        Electronics and Communication Engineering   35.0               2240
#  24.0  Computer Science and Engineering             0.0               2380
# ...

# %%
c = df[df['CodeKata Score'] > 15000]
c.to_csv('codekatascore.csv',index=False)
print(pd.read_csv("codekatascore.csv"))
d =df[(10000 <= df['CodeKata Score']) & (df['CodeKata Score'] <= 15000)]
print(len(d))
d.to_csv('ReachedExpectations.csv',index=False)
print(pd.read_csv("ReachedExpectations.csv"))

e =df[(7000 <= df['CodeKata Score']) & (df['CodeKata Score'] <= 10000)]
print(len(e))
e.to_csv('Needimprovement.csv',index=False)
print(pd.read_csv("Needimprovement.csv"))

f =df[(7000 < df['CodeKata Score'])]
print(len(f))
f.to_csv('Unsatisfactory.csv',index=False)
print(pd.read_csv("Unsatisfactory.csv"))
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 3  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0
# 4
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
print(df[['Previous Geekions','CodeKata Score']].mean())
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
print("no.of. students participated")
print(len(df['Name']))
# Out:
# no.of. students participated
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
print(df[['python','mysql','python_en','computational_thinking']].mean())

print(df.nlargest(3, ['CodeKata Score']))

print(df.nlargest(3, ['Previous Geekions']))

df.plot.pie(y='CodeKata Score', figsize=(5,5),labels=df['Department'])
plt.show()
# Out:
# python                    54.352941
# mysql                     23.500000
# python_en                 29.657143
# computational_thinking     2.200000
# dtype: float64
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# ...

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
g = df[df['Department'] == 'Computer Science and Engineering']
j = g.nlargest(3,['CodeKata Score'])
print(j)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
h = df[df['Department'] == 'Electronics and Communication Engineering']
k = h.nlargest(3,['CodeKata Score'])
print(k)
i = df[df['Department'] == 'Electronics and Electrical Engineering']
l = i.nlargest(3,['CodeKata Score'])
print(l)
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 87  Bodipudi Harini    -1.0   35.0              10040           10040
# 91        Gowtham R    -1.0    4.0               8650            8650
# 6     KALAIARASAN K    85.0   47.0               7750            7880
#
#                                    Department  Rising  python_en  \
# 87  Electronics and Communication Engineering       0        0.0
# 91  Electronics and Communication Engineering       0       60.0
# 6   Electronics and Communication Engineering     130        NaN
#
#     computational_thinking
# 87                    -1.0
# 91                     6.0
# 6                      NaN
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
# 88      VIINU V P    -1.0   24.0               9150            9150
# 92       shifak N    58.0    0.0               5180            8320
#
# ...

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
j.plot.pie(y='CodeKata Score', figsize=(5,5),labels=df['Name'])
plt.title("Computer science and engineering")
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
k.plot.pie(y='CodeKata Score', figsize=(5,5),labels=df['Name'])
plt.title("Electronics and communication engineering")
plt.show()

# %%
l.plot.pie(y='CodeKata Score', figsize=(5,5),labels=df['Name'])
plt.title("Electronics and electrical engineering")
plt.show()
